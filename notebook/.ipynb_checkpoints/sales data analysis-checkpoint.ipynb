# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima.model import ARIMA
from prophet import Prophet
import warnings
import plotly.express as px

# %%
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
df = pd.read_csv("../data/sales.csv")
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         Product ID         Category Sub-Category  \
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9989    False
# 9990    False
# 9991    False
# 9992    False
# 9993    False
# Length: 9994, dtype: bool

# %%
df.info()
df.isnull().sum()
df.drop_duplicates(inplace=True)
df["Order Date"] = pd.to_datetime(df["Order Date"])
df.drop(columns=['Unnamed: 21'],inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"])

df["Sales"] = pd.to_numeric(df["Sales"], errors="coerce")
df["Profit"] = pd.to_numeric(df["Profit"], errors="coerce")
df['Category'] = df['Category'].str.strip()
df['Sub-Category'] = df['Sub-Category'].str.strip()
df['Region'] = df['Region'].str.strip()

df = df.dropna(subset=['Order Date'])
df = df.dropna(subset=['Sales','Profit'])
df['Month'] = df['Order Date'].dt.to_period('M').dt.to_timestamp()

# %%
category_summary = df.groupby("Category")[["Sales", "Profit"]].sum()
category_summary["Profit Margin %"] = (category_summary["Profit"] / category_summary["Sales"]) * 100
category_summary
# Out:
#                        Sales       Profit  Profit Margin %
# Category
# Furniture        741999.7953   18451.2728         2.486695
# Office Supplies  719047.0320  122490.8008        17.035158
# Technology       834227.0970  145046.2041        17.386897

# %%
category_sales = df.groupby('Category')['Sales'].sum().reset_index()
plt.figure(figsize=(8,6))
barplot = sns.barplot(
    data=category_sales,
    x='Category',
    y='Sales',
    palette='Set2'
)
plt.title("Total Sales by Category", fontsize=16, weight='bold')
for index, row in category_sales.iterrows():
    barplot.text(
        index, 
        row['Sales'] + 20000, 
        f"{int(row['Sales']):,}", 
        color='black',
        ha="center",
        fontsize=12,
        weight='bold'
    )

plt.ylabel("Total Sales", fontsize=12)
plt.xlabel("Category", fontsize=12)
plt.show()

# %%
sub_sales = df.groupby("Sub-Category")["Sales"].sum().reset_index().sort_values(by="Sales", ascending=False)

plt.figure(figsize=(12,6))
bar = sns.barplot(data=sub_sales, x="Sub-Category", y="Sales", palette="coolwarm")
plt.title("Total Sales by Sub-Category", fontsize=16, weight="bold")
plt.xticks(rotation=45)

for i, row in sub_sales.iterrows():
    bar.text(i, row["Sales"]+2000, f"{int(row['Sales']):,}", 
             ha="center", fontsize=10, weight="bold")

plt.ylabel("Total Sales")
plt.show()

# %%
category_profit = df.groupby("Category")["Profit"].sum().reset_index()

plt.figure(figsize=(6,3))
bar = sns.barplot(data=category_profit, x="Category", y="Profit", palette="viridis")
plt.title("Total Profit by Category", fontsize=16, weight="bold")

for i, row in category_profit.iterrows():
    bar.text(i, row["Profit"]+2000, f"{int(row['Profit']):,}", 
             ha="center", fontsize=12, weight="bold")

plt.ylabel("Total Profit")
plt.show()

# %%
sub_profit = df.groupby("Sub-Category")["Profit"].sum().reset_index().sort_values(by="Profit", ascending=False)

plt.figure(figsize=(12,6))
bar = sns.barplot(data=sub_profit, x="Sub-Category", y="Profit", palette="crest")
plt.title("Total Profit by Sub-Category", fontsize=16, weight="bold")
plt.xticks(rotation=45)

for i, row in sub_profit.iterrows():
    bar.text(i, row["Profit"]+500, f"{int(row['Profit']):,}", 
             ha="center", fontsize=10, weight="bold")

plt.ylabel("Total Profit")
plt.show()

# %%
region_sales = df.groupby("Region")["Sales"].sum().reset_index()

plt.figure(figsize=(6,3))
bar = sns.barplot(data=region_sales, x="Region", y="Sales", palette="mako")
plt.title("Total Sales by Region", fontsize=16, weight="bold")

for i, row in region_sales.iterrows():
    bar.text(i, row["Sales"]+2000, f"{int(row['Sales']):,}", 
             ha="center", fontsize=12, weight="bold")

plt.ylabel("Total Sales")
plt.show()

# %%
region_profit = df.groupby("Region")["Profit"].sum().reset_index()

plt.figure(figsize=(6,3))
bar = sns.barplot(data=region_profit, x="Region", y="Profit", palette="flare")
plt.title("Total Profit by Region", fontsize=16, weight="bold")

for i, row in region_profit.iterrows():
    bar.text(i, row["Profit"]+500, f"{int(row['Profit']):,}", 
             ha="center", fontsize=12, weight="bold")

plt.ylabel("Total Profit")
plt.show()

# %%
top_products = (
    df.groupby('Product Name')['Sales']
    .sum()
    .nlargest(10)
    .reset_index()
)

fig = px.bar(
    top_products,
    x='Product Name',
    y='Sales',
    title="Top 10 Products by Sales",
    text='Sales',
    color='Sales',
    color_continuous_scale=px.colors.sequential.Blues
)

fig.update_traces(texttemplate='%{text:.2s}', textposition='outside')
fig.update_layout(
    xaxis_tickangle=45,
    plot_bgcolor='white',
    paper_bgcolor='white'
)

fig.show()
# Out:
# <div>                            <div id="f15527ca-bda1-4da1-8efd-4c036c620143" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f15527ca-bda1-4da1-8efd-4c036c620143")) {                    Plotly.newPlot(                        "f15527ca-bda1-4da1-8efd-4c036c620143",                        [{"alignmentgroup":"True","hovertemplate":"Product Name=%{x}<br>Sales=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[61599.824,27453.384000000002,22638.48,21870.576,19823.479,19024.5,18839.686,18374.895,17965.068,17030.311999999998],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[61599.824,27453.384000000002,22638.48,21870.576,19823.479,19024.5,18839.686,18374.895,17965.06
# ...

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"])
monthly_sales = df.groupby(df["Order Date"].dt.to_period("M"))["Sales"].sum().reset_index()
monthly_sales["Order Date"] = monthly_sales["Order Date"].dt.to_timestamp()

plt.figure(figsize=(6,3))
sns.lineplot(data=monthly_sales, x="Order Date", y="Sales", marker="o", color="teal")
plt.title("Monthly Sales Trend", fontsize=16, weight="bold")
plt.ylabel("Sales")
plt.xlabel("Month")
plt.xticks(rotation=45)
plt.grid(True, alpha=0.3)
plt.show()

# %%
monthly_sales["Moving Avg (3M)"] = monthly_sales["Sales"].rolling(3).mean()

plt.figure(figsize=(12,6))
sns.lineplot(data=monthly_sales, x="Order Date", y="Sales", marker="o", label="Sales")
sns.lineplot(data=monthly_sales, x="Order Date", y="Moving Avg (3M)", color="red", linewidth=2, label="3-Month Moving Avg")
plt.title("Time Series Analysis: Monthly Sales with Moving Average", fontsize=16, weight="bold")
plt.ylabel("Sales")
plt.xlabel("Month")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# Ensure datetime index
monthly_sales.index = pd.to_datetime(monthly_sales.index)

# Decompose only the numeric series
decomposition = seasonal_decompose(monthly_sales['Sales'], model="additive", period=12)

fig = decomposition.plot()
fig.set_size_inches(12, 8)

# %%
from statsmodels.tsa.arima.model import ARIMA
monthly_sales = df.resample("M", on="Order Date")["Sales"].sum()
model = ARIMA(monthly_sales, order=(1, 1, 1))
results = model.fit()
forecast = results.get_forecast(steps=12)
forecast_mean = forecast.predicted_mean
forecast_ci = forecast.conf_int()
forecast_mean.index = forecast_mean.index.to_period("M").to_timestamp()

forecast_mean.index = forecast_mean.index.to_period("M").to_timestamp()
forecast_ci.index = forecast_ci.index.to_period("M").to_timestamp()
plt.figure(figsize=(12, 6))
plt.plot(monthly_sales, label="Historical Sales")
plt.plot(forecast_mean, label="Forecasted Sales", color="red")
plt.fill_between(
    forecast_ci.index,
    forecast_ci.iloc[:, 0],
    forecast_ci.iloc[:, 1],
    color="pink",
    alpha=0.3,
    label="Confidence Interval"
)
plt.title("Sales Forecast (ARIMA)")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()
plt.show()

# %%
prophet_df = monthly_sales.reset_index()
prophet_df.columns = ["ds", "y"] 
model = Prophet()
model.fit(prophet_df)
future = model.make_future_dataframe(periods=12, freq="ME")  # 'ME' = Month End
forecast = model.predict(future)
fig = model.plot(forecast)
plt.title("Prophet Forecast - Next 12 Months", fontsize=16)
plt.xlabel("Date")
plt.ylabel("Sales")
plt.tight_layout()
plt.show()
# Out:
# 17:12:45 - cmdstanpy - INFO - Chain [1] start processing
# 17:12:45 - cmdstanpy - INFO - Chain [1] done processing
